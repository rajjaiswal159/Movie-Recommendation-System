# %%
# import required libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# import dataset
books = pd.read_csv("Books.csv")

# %% [markdown]
# # Data Understanding And Preprocessing

# %%
# top 5 rows of dataset
books.head()
# Out:
#    Unnamed: 0        ISBN  book_id  Publication Year  \
# 0           0  0195153448        1              2008
# 1           1  0002005018        2              1997
# 2           2  0060973129        3              2005
# 3           3  0374157065        4              1960
# 4           4  0393045218        5              1925
#
#                         Author  \
# 0              Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré
# 2              Stephenie Meyer
# 3                   Harper Lee
# 4          F. Scott Fitzgerald
#
#                                                Title  AvgRating  \
# 0            The Hunger Games (The Hunger Games, #1)       4.34
# 1  Harry Potter and the Sorcerer's Stone (Harry P...       4.44
# 2                            Twilight (Twilight, #1)       3.57
# 3                              To Kill a Mockingbird       4.25
# 4                                   The Great Gatsby       3.89
#
#                                            Image-URL  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                          Image-URL-S
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...

# %%
# shape of dataset
books.shape
# Out:
# (10000, 9)

# %% [markdown]
# dataset have 9 columns and 10000 row samples

# %%
# drop unnecessary columns of dataset
books.drop("Unnamed: 0", axis=1, inplace=True)

# %%
# Rename columns of dataset
books.rename(columns={
    "Publication Year": "year",
    "Author": "author",
    "Title": "title",
    "AvgRating": "average_rating",
    "Image-URL": "image_url"
}, inplace=True)

# %%
# no. of null values in each column
books.isnull().sum()
# Out:
# ISBN              0
# book_id           0
# year              0
# author            0
# title             0
# average_rating    0
# image_url         0
# Image-URL-S       0
# dtype: int64

# %% [markdown]
# dataset has 0 null values

# %%
# no. of duplicate row samples
books.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# dataset has 0 duplicate row samples

# %%
# datatype of each column
books.dtypes
# Out:
# ISBN               object
# book_id             int64
# year                int64
# author             object
# title              object
# average_rating    float64
# image_url          object
# Image-URL-S        object
# dtype: object

# %%
# typecasting
books["book_id"] = books["book_id"].astype("int32")
books["year"] = books["year"].astype("int32")
books["average_rating"] = books["average_rating"].astype("float32")

# %% [markdown]
# # Popularity Based Filtering

# %%
# filter top 30 books
popular_books = books.sort_values(
    by="average_rating", ascending=False
).head(30)

# %%
# top 5 most popular books
popular_books.head()
# Out:
#             ISBN  book_id  year                                      author  \
# 3627  8807015188     3628  2005                              Bill Watterson
# 861   0451456548      862  2014                           Brandon Sanderson
# 3274  1586480456     3275  2003                 J.K. Rowling, Mary GrandPré
# 7946  1565071298     7947  2002  Anonymous, Lane T. Dennis, Wayne A. Grudem
# 8853  0425125467     8854  1993                             Francine Rivers
#
#                                                   title  average_rating  \
# 3627                     The Complete Calvin and Hobbes            4.82
# 861      Words of Radiance (The Stormlight Archive, #2)            4.77
# 3274  Harry Potter Boxed Set, Books 1-5 (Harry Potte...            4.77
# 7946                                    ESV Study Bible            4.76
# 8853                           Mark of the Lion Trilogy            4.76
#
#                                               image_url  \
# 3627  https://images.gr-assets.com/books/1473064526m...
# 861   https://images.gr-assets.com/books/1391535251m...
# 3274  https://s.gr-assets.com/assets/nophoto/book/11...
# 7946  https://images.gr-assets.com/books/1410151002m...
# 8853  https://images.gr-assets.com/books/1349032180m...
#
#                                             Image-URL-S
# 3627  https://images.gr-assets.com/books/1473064526s...
# 861   https://images.gr-assets.com/books/1391535251s...
# 3274  https://s.gr-assets.com/assets/nophoto/book/50...
# 7946  https://images.gr-assets.com/books/1410151002s...
# 8853  https://images.gr-assets.com/books/1349032180s...

# %% [markdown]
# # Content-based Ftering

# %%
# create combined column for vectorization
books["text"] = books["title"] + " " + books["author"]

# %%
# convert text into vectors
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(books["text"])

# compute cosine similarity
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
# function to recommend similar books
def recommend(book_title):
    idx = books[books["title"] == book_title].index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:11]
    book_indices = [i[0] for i in sim_scores]
    return books.iloc[book_indices][["title", "author", "year", "average_rating"]]

# %%
# test recommend function
recommend("The Complete Calvin and Hobbes")
# Out:
#                                                   title  \
# 1009  The Essential Calvin and Hobbes: A Calvin and ...
# 6589  The Authoritative Calvin and Hobbes: A Calvin ...
# 6919                The Indispensable Calvin and Hobbes
# 779                                   Calvin and Hobbes
# 6360  There's Treasure Everywhere: A Calvin and Hobb...
# 4482  It's a Magical World: A Calvin and Hobbes Coll...
# 1787       The Calvin and Hobbes Tenth Anniversary Book
# 5579             The Calvin and Hobbes Lazy Sunday Book
# 5206  The Days Are Just Packed: A Calvin and Hobbes ...
# 7253  Homicidal Psycho Jungle Cat: A Calvin and Hobb...
#
#                             author  year  average_rating
# 1009                Bill Watterson  1988            4.65
# 6589                Bill Watterson  1990            4.73
# 6919                Bill Watterson  1992            4.73
# 779   Bill Watterson, G.B. Trudeau  1987            4.61
# 6360                Bill Watterson  1996            4.74
# 4482                Bill Watterson  1996            4.75
# 1787                Bill Watterson  1995            4.63
# 5579                Bill Watterson  1989            4.66
# 5206                Bill Watterson  1993            4.68
# 7253                Bill Watterson  1994            4.71
